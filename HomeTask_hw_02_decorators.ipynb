# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
def benchmark_old(func):
    """Выводит время выполнения декорируемой функции"""

    import functools
    import time
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.perf_counter()
        value = func(*args, **kwargs)
        end_time = time.perf_counter()
        run_time = end_time - start_time
        print(f"Функция {func.__name__}() выполнена за {run_time:.4f} c")
        return value
    return wrapper

# %%
#Пример другой реализации:

def benchmark(func):

    import functools
    
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        if not hasattr(func, 'called'):
            func.called = True
            start_time = time.time()
            result = func(*args, **kwargs)
            end_time = time.time()
            #print(f"Время выполнения функции {func.__name__}: {end_time - start_time} секунд")
            print(f"Время выполнения функции : {end_time - start_time} секунд")
            
        else:
            result = func(*args, **kwargs)
        return result

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """
    import functools

    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        args_repr = [repr(a) for a in args]
        kwargs_repr = [f"{k}={repr(v)}" for k, v in kwargs.items()]
        signature = ", ".join(args_repr + kwargs_repr)
        print(f"Была вызвана функция {func.__name__} с параметрами: ({signature})")
        value = func(*args, **kwargs)
        print(f" Функция {func.__name__!r} возвращает {repr(value)}")
        return value

    return wrapper

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    import functools

    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        wrapper.num_calls += 1
        #print(f" Функция {func.__name__}() была вызвана {wrapper.num_calls} of раз!")
        print(f" Функция была вызвана {wrapper.num_calls} of раз!")
        return func(*args, **kwargs)
    wrapper.num_calls = 0

    return wrapper

# %% [markdown]
# ## Задание 4

# %% [markdown]
# #Немного википедии для понимания
#
# Мемоизация (Кэш) (англ. memoization от англ. memory и англ. optimization) — пример использования кэша при разработке программного обеспечения, в программировании сохранение результатов выполнения функций для предотвращения повторных вычислений. Это один из способов оптимизации, применяемый для увеличения скорости выполнения компьютерных программ. Перед вызовом функции проверяется, вызывалась ли функция ранее:
#
# если не вызывалась, то функция вызывается, и результат её выполнения сохраняется;
# если вызывалась, то используется сохранённый результат.
# Мемоизация может использоваться не только для увеличения скорости работы программы. Например, она используется при взаимно-рекурсивном нисходящем синтаксическом разборе в обобщённом алгоритме нисходящего синтаксического анализа.

# %%
def memo(func):

  """Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми"""
  import functools
    
  cache ={}

  @functools.wraps(func)
  def fmemo(*args, **kwargs):
      memo_key = args + tuple(kwargs.items())
      if memo_key not in fmemo.memo:
          fmemo.memo[memo_key] = func(*args, **kwargs)
      return fmemo.memo[memo_key]
      fmemo.memo = cache
      return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
#@benchmark
@benchmark_old
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
#  Функция word_count() была вызвана 1 of раз!
# Была вызвана функция word_count с параметрами: ('whole')
# Функция word_count() выполнена за 1.7800 c
#  Функция 'word_count' возвращает 'Cлово whole встречается 176 раз'
# Cлово whole встречается 176 раз

# %%
@benchmark_old
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения

fib(10)
# Out:
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0004 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0006 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0017 c
# Функция fib() выполнена за 0.0055 c
# Функция fib() выполнена за 0.0058 c
# Функция fib() выполнена за 0.0064 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0004 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0011 c
# Функция fib() выполнена за 0.0012 c
# Функция fib() выполнена за 0.0013 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0004 c
# Функция fib() выполнена за 0.0018 c
# Функция fib() выполнена за 0.0023 c
# Функция fib() выполнена за 0.0088 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0005 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0091 c
# Функция fib() выполнена за 0.0093 c
# Функция fib() выполнена за 0.0096 c
# Функция fib() выполнена за 0.0102 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0061 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0063 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0004 c
# Функция fib() выполнена за 0.0068 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0012 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0012 c
# Функция fib() выполнена за 0.0014 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0017 c
# Функция fib() выполнена за 0.0086 c
# Функция fib() выполнена за 0.0188 c
# Функция fib() выполнена за 0.0276 c
# 55

# %%
@memo
@benchmark_old
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)

# %%
# измеряем время выполнения
fib(10)
# Out:
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0004 c
# Функция fib() выполнена за 0.0018 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0016 c
# Функция fib() выполнена за 0.0016 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0008 c
# Функция fib() выполнена за 0.0008 c
# Функция fib() выполнена за 0.0009 c
# Функция fib() выполнена за 0.0025 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0013 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0015 c
# Функция fib() выполнена за 0.0016 c
# Функция fib() выполнена за 0.0041 c
# Функция fib() выполнена за 0.0059 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0003 c
# Функция fib() выполнена за 0.0005 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0005 c
# Функция fib() выполнена за 0.0005 c
# Функция fib() выполнена за 0.0006 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0015 c
# Функция fib() выполнена за 0.0016 c
# Функция fib() выполнена за 0.0016 c
# Функция fib() выполнена за 0.0017 c
# Функция fib() выполнена за 0.0023 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0002 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0024 c
# Функция fib() выполнена за 0.0024 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0000 c
# Функция fib() выполнена за 0.0001 c
# Функция fib() выполнена за 0.0025 c
# Функция fib() выполнена за 0.0026 c
# Функция fib() выполнена за 0.0029 c
# Функция fib() выполнена за 0.0052 c
# Функция fib() выполнена за 0.0097 c
# Функция fib() выполнена за 0.0156 c
# 55

# %%
# из рецензии:
#что-то пошло не так с декоратором benchmark. 
#Для Фибоначчи, он не должен выводиться для каждого рекурсивного вывоза, а должен показывать время в целом. 

#.....а ведь он мне сразу не понравился (причем два раза). 
# ладно продолжаем...

# %%
#Пример другой реализации:

def benchmark(func):

    import functools
    
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        if not hasattr(func, 'called'):
            func.called = True
            start_time = time.time()
            result = func(*args, **kwargs)
            end_time = time.time()
            #print(f"Время выполнения функции {func.__name__}: {end_time - start_time} секунд")
            print(f"Время выполнения функции benchmark: {end_time - start_time} секунд")
        else:
            result = func(*args, **kwargs)
        return result

# %%
#В дополнение можете провести еще пару экспериментов:

#1. Замерьте время выполнения функции fib(n) не только с декоратором @memo, 
#   без него, но и с декоратором @lru_cache из библиотеки functools, 
#   и по результатам измерения написать общий вывод (например, в виде мнострочного комментария).
#2. Добавить декоратор @counter к функции fib(n) и проанализировать результат.

# ....

# %%
@benchmark_old
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)

# %%
# измеряем время выполнения
fibonacci(10)
# Out:
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0006 c
# Функция fibonacci() выполнена за 0.0007 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0008 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0009 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0012 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0003 c
# Функция fibonacci() выполнена за 0.0005 c
# Функция fibonacci() выполнена за 0.0017 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0004 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0005 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0005 c
# Функция fibonacci() выполнена за 0.0007 c
# Функция fibonacci() выполнена за 0.0010 c
# Функция fibonacci() выполнена за 0.0028 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0008 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0005 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0007 c
# Функция fibonacci() выполнена за 0.0015 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0003 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0004 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0004 c
# Функция fibonacci() выполнена за 0.0022 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0003 c
# Функция fibonacci() выполнена за 0.0027 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0023 c
# Функция fibonacci() выполнена за 0.0024 c
# Функция fibonacci() выполнена за 0.0051 c
# Функция fibonacci() выполнена за 0.0074 c
# Функция fibonacci() выполнена за 0.0102 c
# 55

# %%
@counter
@benchmark_old
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)

# измеряем время выполнения
fibonacci(10)
# Out:
#  Функция fibonacci() была вызвана 1 of раз!
#  Функция fibonacci() была вызвана 2 of раз!
#  Функция fibonacci() была вызвана 3 of раз!
#  Функция fibonacci() была вызвана 4 of раз!
#  Функция fibonacci() была вызвана 5 of раз!
#  Функция fibonacci() была вызвана 6 of раз!
#  Функция fibonacci() была вызвана 7 of раз!
#  Функция fibonacci() была вызвана 8 of раз!
#  Функция fibonacci() была вызвана 9 of раз!
#  Функция fibonacci() была вызвана 10 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 11 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0013 c
#  Функция fibonacci() была вызвана 12 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0014 c
#  Функция fibonacci() была вызвана 13 of раз!
#  Функция fibonacci() была вызвана 14 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 15 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0014 c
#  Функция fibonacci() была вызвана 16 of раз!
#  Функция fibonacci() была вызвана 17 of раз!
#  Функция fibonacci() была вызвана 18 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 19 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0009 c
#  Функция fibonacci() была вызвана 20 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0011 c
# Функция fibonacci() выполнена за 0.0026 c
#  Функция fibonacci() была вызвана 21 of раз!
#  Функция fibonacci() была вызвана 22 of раз!
#  Функция fibonacci() была вызвана 23 of раз!
#  Функция fibonacci() была вызвана 24 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 25 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 26 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 27 of раз!
#  Функция fibonacci() была вызвана 28 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 29 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0028 c
#  Функция fibonacci() была вызвана 30 of раз!
#  Функция fibonacci() была вызвана 31 of раз!
#  Функция fibonacci() была вызвана 32 of раз!
#  Функция fibonacci() была вызвана 33 of раз!
#  Функция fibonacci() была вызвана 34 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 35 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 36 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 37 of раз!
#  Функция fibonacci() была вызвана 38 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 39 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 40 of раз!
#  Функция fibonacci() была вызвана 41 of раз!
#  Функция fibonacci() была вызвана 42 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 43 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 44 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0004 c
# Функция fibonacci() выполнена за 0.0033 c
#  Функция fibonacci() была вызвана 45 of раз!
#  Функция fibonacci() была вызвана 46 of раз!
#  Функция fibonacci() была вызвана 47 of раз!
#  Функция fibonacci() была вызвана 48 of раз!
#  Функция fibonacci() была вызвана 49 of раз!
#  Функция fibonacci() была вызвана 50 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 51 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 52 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 53 of раз!
#  Функция fibonacci() была вызвана 54 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 55 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 56 of раз!
#  Функция fibonacci() была вызвана 57 of раз!
#  Функция fibonacci() была вызвана 58 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 59 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 60 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0026 c
#  Функция fibonacci() была вызвана 61 of раз!
#  Функция fibonacci() была вызвана 62 of раз!
#  Функция fibonacci() была вызвана 63 of раз!
#  Функция fibonacci() была вызвана 64 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 65 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0040 c
#  Функция fibonacci() была вызвана 66 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0041 c
#  Функция fibonacci() была вызвана 67 of раз!
#  Функция fibonacci() была вызвана 68 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 69 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0042 c
# Функция fibonacci() выполнена за 0.0068 c
# Функция fibonacci() выполнена за 0.0101 c
#  Функция fibonacci() была вызвана 70 of раз!
#  Функция fibonacci() была вызвана 71 of раз!
#  Функция fibonacci() была вызвана 72 of раз!
#  Функция fibonacci() была вызвана 73 of раз!
#  Функция fibonacci() была вызвана 74 of раз!
#  Функция fibonacci() была вызвана 75 of раз!
#  Функция fibonacci() была вызвана 76 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 77 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 78 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 79 of раз!
#  Функция fibonacci() была вызвана 80 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 81 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 82 of раз!
#  Функция fibonacci() была вызвана 83 of раз!
#  Функция fibonacci() была вызвана 84 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 85 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 86 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0003 c
#  Функция fibonacci() была вызвана 87 of раз!
#  Функция fibonacci() была вызвана 88 of раз!
#  Функция fibonacci() была вызвана 89 of раз!
#  Функция fibonacci() была вызвана 90 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 91 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 92 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 93 of раз!
#  Функция fibonacci() была вызвана 94 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 95 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0006 c
#  Функция fibonacci() была вызвана 96 of раз!
#  Функция fibonacci() была вызвана 97 of раз!
#  Функция fibonacci() была вызвана 98 of раз!
#  Функция fibonacci() была вызвана 99 of раз!
#  Функция fibonacci() была вызвана 100 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 101 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 102 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0003 c
#  Функция fibonacci() была вызвана 103 of раз!
#  Функция fibonacci() была вызвана 104 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 105 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0004 c
#  Функция fibonacci() была вызвана 106 of раз!
#  Функция fibonacci() была вызвана 107 of раз!
#  Функция fibonacci() была вызвана 108 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 109 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 110 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0005 c
# Функция fibonacci() выполнена за 0.0011 c
# Функция fibonacci() выполнена за 0.0114 c
#  Функция fibonacci() была вызвана 111 of раз!
#  Функция fibonacci() была вызвана 112 of раз!
#  Функция fibonacci() была вызвана 113 of раз!
#  Функция fibonacci() была вызвана 114 of раз!
#  Функция fibonacci() была вызвана 115 of раз!
#  Функция fibonacci() была вызвана 116 of раз!
#  Функция fibonacci() была вызвана 117 of раз!
#  Функция fibonacci() была вызвана 118 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 119 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0003 c
#  Функция fibonacci() была вызвана 120 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0005 c
#  Функция fibonacci() была вызвана 121 of раз!
#  Функция fibonacci() была вызвана 122 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 123 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0013 c
#  Функция fibonacci() была вызвана 124 of раз!
#  Функция fibonacci() была вызвана 125 of раз!
#  Функция fibonacci() была вызвана 126 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 127 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 128 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0039 c
#  Функция fibonacci() была вызвана 129 of раз!
#  Функция fibonacci() была вызвана 130 of раз!
#  Функция fibonacci() была вызвана 131 of раз!
#  Функция fibonacci() была вызвана 132 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 133 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 134 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 135 of раз!
#  Функция fibonacci() была вызвана 136 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 137 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0041 c
#  Функция fibonacci() была вызвана 138 of раз!
#  Функция fibonacci() была вызвана 139 of раз!
#  Функция fibonacci() была вызвана 140 of раз!
#  Функция fibonacci() была вызвана 141 of раз!
#  Функция fibonacci() была вызвана 142 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 143 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 144 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 145 of раз!
#  Функция fibonacci() была вызвана 146 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 147 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 148 of раз!
#  Функция fibonacci() была вызвана 149 of раз!
#  Функция fibonacci() была вызвана 150 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 151 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 152 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0003 c
# Функция fibonacci() выполнена за 0.0045 c
#  Функция fibonacci() была вызвана 153 of раз!
#  Функция fibonacci() была вызвана 154 of раз!
#  Функция fibonacci() была вызвана 155 of раз!
#  Функция fibonacci() была вызвана 156 of раз!
#  Функция fibonacci() была вызвана 157 of раз!
#  Функция fibonacci() была вызвана 158 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 159 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 160 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 161 of раз!
#  Функция fibonacci() была вызвана 162 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 163 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 164 of раз!
#  Функция fibonacci() была вызвана 165 of раз!
#  Функция fibonacci() была вызвана 166 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 167 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 168 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0003 c
#  Функция fibonacci() была вызвана 169 of раз!
#  Функция fibonacci() была вызвана 170 of раз!
#  Функция fibonacci() была вызвана 171 of раз!
#  Функция fibonacci() была вызвана 172 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 173 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
#  Функция fibonacci() была вызвана 174 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0002 c
#  Функция fibonacci() была вызвана 175 of раз!
#  Функция fibonacci() была вызвана 176 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 177 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0033 c
# Функция fibonacci() выполнена за 0.0037 c
# Функция fibonacci() выполнена за 0.0082 c
# Функция fibonacci() выполнена за 0.0198 c
# 55

# %%
from functools import lru_cache

@lru_cache
@counter
@benchmark_old
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)
# Out:
#  Функция fibonacci() была вызвана 1 of раз!
#  Функция fibonacci() была вызвана 2 of раз!
#  Функция fibonacci() была вызвана 3 of раз!
#  Функция fibonacci() была вызвана 4 of раз!
#  Функция fibonacci() была вызвана 5 of раз!
#  Функция fibonacci() была вызвана 6 of раз!
#  Функция fibonacci() была вызвана 7 of раз!
#  Функция fibonacci() была вызвана 8 of раз!
#  Функция fibonacci() была вызвана 9 of раз!
#  Функция fibonacci() была вызвана 10 of раз!
# Функция fibonacci() выполнена за 0.0000 c
#  Функция fibonacci() была вызвана 11 of раз!
# Функция fibonacci() выполнена за 0.0000 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0001 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0002 c
# Функция fibonacci() выполнена за 0.0003 c
# 55

# %%
@counter
@benchmark
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)

# измеряем время выполнения
fibonacci(10)
# Out:
#  Функция была вызвана 1 of раз!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DA7E~1\AppData\Local\Temp/ipykernel_14560/394210800.py in <module>
#       7
#       8 # измеряем время выполнения
# ----> 9 fibonacci(10)
#
# C:\Users\DA7E~1\AppData\Local\Temp/ipykernel_14560/3381353585.py in wrapper(*args, **kwargs)
#      10         #print(f" Функция {func.__name__}() была вызвана {wrapper.num_calls} of раз!")
#      11         print(f" Функция была вызвана {wrapper.num_calls} of раз!")
# ---> 12         return func(*args, **kwargs)
#      13     wrapper.num_calls = 0
#      14
#
# TypeError: 'NoneType' object is not callable

# %%
# измеряем время выполнения
fibonacci(40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DA7E~1\AppData\Local\Temp/ipykernel_14560/3990785959.py in <module>
#       1 # измеряем время выполнения
# ----> 2 fibonacci(40)
#
# TypeError: 'NoneType' object is not callable

# %%
def benchmark_time(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции выполненый через time
    """

    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        execution_time = end_time - start_time
        print(f'Время выполнения функции {func.__name__}: {execution_time}')
        return result

    return wrapper

# %%
@lru_cache
@counter
@benchmark_time
def fibonacci(num):
    if num < 2:
        return num
    return fibonacci(num - 1) + fibonacci(num - 2)

fibonacci(40)
# Out:
#  Функция была вызвана 1 of раз!
#  Функция была вызвана 2 of раз!
#  Функция была вызвана 3 of раз!
#  Функция была вызвана 4 of раз!
#  Функция была вызвана 5 of раз!
#  Функция была вызвана 6 of раз!
#  Функция была вызвана 7 of раз!
#  Функция была вызвана 8 of раз!
#  Функция была вызвана 9 of раз!
#  Функция была вызвана 10 of раз!
#  Функция была вызвана 11 of раз!
#  Функция была вызвана 12 of раз!
#  Функция была вызвана 13 of раз!
#  Функция была вызвана 14 of раз!
#  Функция была вызвана 15 of раз!
#  Функция была вызвана 16 of раз!
#  Функция была вызвана 17 of раз!
#  Функция была вызвана 18 of раз!
#  Функция была вызвана 19 of раз!
#  Функция была вызвана 20 of раз!
#  Функция была вызвана 21 of раз!
#  Функция была вызвана 22 of раз!
#  Функция была вызвана 23 of раз!
#  Функция была вызвана 24 of раз!
#  Функция была вызвана 25 of раз!
#  Функция была вызвана 26 of раз!
#  Функция была вызвана 27 of раз!
#  Функция была вызвана 28 of раз!
#  Функция была вызвана 29 of раз!
#  Функция была вызвана 30 of раз!
#  Функция была вызвана 31 of раз!
#  Функция была вызвана 32 of раз!
#  Функция была вызвана 33 of раз!
#  Функция была вызвана 34 of раз!
#  Функция была вызвана 35 of раз!
#  Функция была вызвана 36 of раз!
#  Функция была вызвана 37 of раз!
#  Функция была вызвана 38 of раз!
#  Функция была вызвана 39 of раз!
#  Функция была вызвана 40 of раз!
# Время выполнения функции fibonacci: 0.0
#  Функция была вызвана 41 of раз!
# Время выполнения функции fibonacci: 0.0
# Время выполнения функции fibonacci: 0.0009987354278564453
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.002001047134399414
# Время выполнения функции fibonacci: 0.0030014514923095703
# Время выполнения функции fibonacci: 0.0030014514923095703
# Время выполнения функции fibonacci: 0.0030014514923095703
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.003998517990112305
# Время выполнения функции fibonacci: 0.004995822906494141
# Время выполнения функции fibonacci: 0.004995822906494141
# Время выполнения функции fibonacci: 0.004995822906494141
# Время выполнения функции fibonacci: 0.004995822906494141
# Время выполнения функции fibonacci: 0.004995822906494141
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.005997896194458008
# Время выполнения функции fibonacci: 0.00699925422668457
# Время выполнения функции fibonacci: 0.00699925422668457
# Время выполнения функции fibonacci: 0.00699925422668457
# Время выполнения функции fibonacci: 0.00699925422668457
# Время выполнения функции fibonacci: 0.00699925422668457
# 102334155
